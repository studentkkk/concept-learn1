# %% [markdown]
# # 01 · 学生练习笔记本
#
# 本文件是 **python-basic-course** 的配套练习本，对应 `_series/concepts.md` 中的知识点。
#
# 使用方式：
#
# 1. 在右上角内核选择器中选择 Python 3.12 解释器。
# 2. 选中单元格，按 `Shift+Enter` 执行。
# 3. 先运行下面的“环境自检”单元格，确认输出正常。

# %% [markdown]
# ## 环境自检

# %%
import sys

print("解释器路径:", sys.executable)
print("Python 版本:", sys.version.split()[0])

print("Hello, Python")
print("1 + 1 =", 1 + 1)

# %% [markdown]
# ## 练习区
#
# 在下面新增单元格开始练习。

# %%
#第1格
a = 10
print(a)
print(type(a))

b = 3.14
print(b)
print(type(b))
# Out:
# 10
# <class 'int'>
# 3.14
# <class 'float'>

# %%
#第2格
s = "你好python"
print(s)
print(type(s))
# Out:
# 你好python
# <class 'str'>

# %%
#第3格
flag1 = True
flag2 = False
print(flag1,flag2)
print(type(flag1))
# Out:
# True False
# <class 'bool'>

# %%
#第4格
mylist = [1,2,3,4]
print(mylist)
print(type(mylist))
# Out:
# [1, 2, 3, 4]
# <class 'list'>

# %%
#第5格
mydict = {"name":"张三","age":18}
print(mydict)
print(type(mydict))
# Out:
# {'name': '张三', 'age': 18}
# <class 'dict'>

# %%
#第6格
mytuple = (10,20,30)
print(mytuple)
print(type(mytuple))
# Out:
# (10, 20, 30)
# <class 'tuple'>

# %%
#第7格
myset = {1,2,3}
print(myset)
print(type(myset))

n = None
print(n)
print(type(n))
# Out:
# {1, 2, 3}
# <class 'set'>
# None
# <class 'NoneType'>

# %%
#第8格
num1 = 7
num2 = 2
print(num1 + num2)
print(num1 - num2)
print(num1 * num2)
print(num1 / num2)
print(num1 // num2)
print(num1 % num2)
print(num1 ** num2)

str1 = "hi"
str2 = "python"
print(str1 + str2)
print(str1 * 3)

print(True and False)
print(True or False)
print(not True)

li = [5,6,7,8]
print(li[0])
print(len(li))
# Out:
# 9
# 5
# 14
# 3.5
# 3
# 1
# 49
# hipython
# hihihi
# False
# True
# False
# 5
# 4
